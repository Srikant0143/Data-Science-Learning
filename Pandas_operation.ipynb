# %%
import pandas as pd
import numpy as np

# %%
datadf=pd.read_csv("k_circle_sales.csv")
datadf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
datadf.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
datadf.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods     214.5            OUT013
# 8519        Baking Goods     108.2            OUT045
# 8520  Health and Hygiene      85.1            OUT035
# 8521         Snack Foods     103.1            OUT018
# 8522         Soft Drinks      75.5            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN                  NaN
# ...

# %%
datadf.shape
# Out:
# (8523, 13)

# %%
datadf.info()   # ()  means it is function
# object means it is string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7775 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Profit                     8523 non-null   float64
# ...

# %%
# how to check the null data (missing data)
datadf.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
datadf.isnull().sum()
# datadf.isna().sum()  same as above
# Out:
# Item_Identifier                 0
# Item_Weight                   748
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
# handling the missing data
x=datadf.copy()

# %%
x.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   748
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
x.shape
# Out:
# (8523, 13)

# %%
# drop the null values
x.dropna(inplace=True)

# %%
x.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
x.shape
# Out:
# (5365, 13)

# %%
8523-5365
# Out:
# 3158

# %%
datadf.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
datadf.shape
# Out:
# (8523, 13)

# %%
# fillna method is used to fill the missing value
y=datadf.copy()

# %%
y.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   748
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
y.fillna(value=0, inplace=True)

# %%
y.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
y.shape
# Out:
# (8523, 13)

# %%
datadf.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   748
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
# replace the missing value in item_ weight with avg of the data
datadf["Item_Weight"].fillna(datadf["Item_Weight"].mean(),inplace=True)

# %%
datadf.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
datadf["Outlet_Size"].mode()
# Out:
# 0    Medium
# dtype: object

# %%
# replace the missing value in Outlet_Size with mode of the data
datadf["Outlet_Size"].fillna(datadf["Outlet_Size"].mode()[0],inplace=True)

# %%
datadf.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
datadf["Outlet_Location_Type"].mode()
# Out:
# 0    Tier 2
# dtype: object

# %%
# replace the missing value in Outlet_Location_Type with mode of the data
datadf["Outlet_Location_Type"].fillna(datadf["Outlet_Location_Type"].mode()[0],inplace=True)

# %%
datadf.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
datadf.shape
# Out:
# (8523, 13)

# %%
type(datadf)
# Out:
# pandas.core.frame.DataFrame

# %%
datadf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
# number of diff category of data in a column
datadf["Item_Fat_Content"].nunique()
# Out:
# 5

# %%
# whatt all diff category of data in a column
datadf["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
# display how many diff value in each category in item fat content
datadf["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# How to access the single columns
datadf["Outlet_Size"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 8518      High
# 8519    Medium
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
# How to access the multiple columns
datadf[['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content
# 0              FDA15        9.300          Low Fat
# 1              DRC01        5.920          Regular
# 2              FDN15       17.500          Low Fat
# 3              FDX07       19.200          Regular
# 4              NCD19        8.930          Low Fat
# ...              ...          ...              ...
# 8518           FDF22        6.865          Low Fat
# 8519           FDS36        8.380          Regular
# 8520           NCJ29       10.600          Low Fat
# 8521           FDN46        7.210          Regular
# 8522           DRG01       14.800          Low Fat
#
# [8523 rows x 3 columns]

# %%
# use loc method to display 50thto 60th row of outlet size Item_Outlet_Sales', 'Profit'

# %%
datadf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
datadf.loc[50:60,["Outlet_Size", "Item_Outlet_Sales", "Profit"]]
# Out:
#    Outlet_Size  Item_Outlet_Sales  Profit
# 50       Small          3134.5864     7.4
# 51        High           850.8924    14.7
# 52        High           810.9444    11.2
# 53      Medium          3121.2704    14.7
# 54      Medium          4815.0656    13.0
# 55      Medium          6258.5200    12.8
# 56      Medium          2117.2440    14.4
# 57      Medium           796.9626    14.8
# 58       Small          4910.2750    14.4
# 59       Small           892.1720    14.7
# 60      Medium          3185.1872    14.6

# %%
# display the item weight and MRP of the following transaction 10,12,56,89,95

datadf.loc[[10,12,56,89,95],['Item_Weight', 'Item_MRP']]
# Out:
#     Item_Weight  Item_MRP
# 10       11.800      45.5
# 12       15.100     145.5
# 56        9.195     106.2
# 89       20.850     117.3
# 95        0.000     120.0

# %%
# display the'Outlet_Size' & 'Profit' of the following transaction 100 to 200

# %%
datadf.iloc[100:201,[8,12]]   # iloc method index value needed
# Out:
#     Outlet_Size  Profit
# 100      Medium    14.3
# 101      Medium    11.2
# 102      Medium    14.0
# 103        High    14.6
# 104      Medium    14.2
# ..          ...     ...
# 196       Small    12.1
# 197      Medium    12.7
# 198      Medium    14.1
# 199      Medium    14.6
# 200      Medium    14.5
#
# [101 rows x 2 columns]

# %%
# sorting 
# display the data based on small to large value of item weight
datadf.sort_values(by=["Item_Weight"],ascending=False).head(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 229            FDX25       100.00          Low Fat         0.101562    Canned
# 4468           FDC02        21.35          Low Fat         0.068822    Canned
# 2368           FDC02        21.35          Low Fat         0.068809    Canned
# 2802           FDC02        21.35          Low Fat         0.068765    Canned
# 43             FDC02        21.35          Low Fat         0.069103    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 229      181.9            OUT027                       1985      Medium
# 4468     258.3            OUT046                       1997       Small
# 2368     258.5            OUT035                       2004       Small
# 2802     260.4            OUT013                       1987        High
# 43       259.9            OUT018                       2009      Medium
#
# ...

# %%
datadf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
datadf.sort_values(by=["Item_Weight","Item_MRP"],ascending=[False,False]).head(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 229            FDX25       100.00          Low Fat         0.101562    Canned
# 2802           FDC02        21.35          Low Fat         0.068765    Canned
# 43             FDC02        21.35          Low Fat         0.069103    Canned
# 2368           FDC02        21.35          Low Fat         0.068809    Canned
# 483            FDC02        21.35          Low Fat         0.115195    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 229      181.9            OUT027                       1985      Medium
# 2802     260.4            OUT013                       1987        High
# 43       259.9            OUT018                       2009      Medium
# 2368     258.5            OUT035                       2004       Small
# 483      258.3            OUT010                       1998      Medium
#
# ...

# %%
datadf.sort_values(by=["Item_Weight","Item_MRP"],ascending=[False,True]).head(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 229            FDX25       100.00          Low Fat         0.101562
# 6389           FDR07        21.35          Low Fat         0.078061
# 4257           FDR07        21.35          Low Fat         0.130127
# 483            FDC02        21.35          Low Fat         0.115195
# 4468           FDC02        21.35          Low Fat         0.068822
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 229                  Canned     181.9            OUT027
# 6389  Fruits and Vegetables      96.0            OUT018
# 4257  Fruits and Vegetables      96.2            OUT010
# 483                  Canned     258.3            OUT010
# 4468                 Canned     258.3            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 229                        1985      Medium               Tier 2
# 6389                       2009      Medium               Tier 2
# ...

# %%
# filtering
# display the data having outlet sale >3000
datadf[datadf["Item_Outlet_Sales"]>3000]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15       9.3000          Low Fat         0.016047
# 7              FDP10      11.6881          Low Fat         0.127470
# 9              FDU28      19.2000          Regular         0.094450
# 20             FDN22      18.8500          Regular         0.138190
# 21             FDW12      11.6881          Regular         0.035400
# ...              ...          ...              ...              ...
# 8504           NCN18       0.0000          Low Fat         0.124111
# 8506           DRF37      17.2500          Low Fat         0.084676
# 8510           FDN58      13.8000          Regular         0.056862
# 8511           FDF05      17.5000          Low Fat         0.026980
# 8517           FDF53      20.7500              reg         0.083607
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0            Dairy     249.8            OUT049                       1999
# ...

# %%
# display the data having outlet sale >3000  and profit is >13

# %%
datadf[(datadf["Item_Outlet_Sales"]>3000) & (datadf["Profit"]>13)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10      11.6881          Low Fat         0.127470
# 9              FDU28      19.2000          Regular         0.094450
# 20             FDN22      18.8500          Regular         0.138190
# 21             FDW12      11.6881          Regular         0.035400
# 24             FDR28      13.8500          Regular         0.025896
# ...              ...          ...              ...              ...
# 8503           FDQ44      20.5000          Low Fat         0.036133
# 8504           NCN18       0.0000          Low Fat         0.124111
# 8506           DRF37      17.2500          Low Fat         0.084676
# 8511           FDF05      17.5000          Low Fat         0.026980
# 8517           FDF53      20.7500              reg         0.083607
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods     107.8            OUT027
# ...

# %%
datadf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
# display the item_weight

# %%
datadf[datadf["Item_Weight"] == 21.25]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 148            FDA45        21.25          Low Fat         0.155350
# 934            FDQ21        21.25          Low Fat         0.019502
# 2232           FDT03        21.25          Low Fat         0.009997
# 3478           FDQ21        21.25          Low Fat         0.019423
# 3632           FDT03        21.25          Low Fat         0.010039
# 4054           FDT03        21.25          Low Fat         0.016736
# 4764           FDT03        21.25          Low Fat         0.010055
# 5111           NCO42        21.25               LF         0.024651
# 5393           FDT03        21.25          Low Fat         0.010019
# 5457           NCO42        21.25          Low Fat         0.024706
# 5717           NCX17        21.25          Low Fat         0.114246
# 5782           FDA45        21.25          Low Fat         0.155250
# 5959           FDQ21        21.25          low fat         0.019407
# ...

# %%
# grouping

data=pd.DataFrame({"Gender":["M","F","M","M","F","M"], "age":[34,67,56,72,45,8],"height":[5.2,6.7,3.2,6,8,4.5]})
data
# Out:
#   Gender  age  height
# 0      M   34     5.2
# 1      F   67     6.7
# 2      M   56     3.2
# 3      M   72     6.0
# 4      F   45     8.0
# 5      M    8     4.5

# %%
data.groupby("Gender").mean()
# Out:
#          age  height
# Gender
# F       56.0   7.350
# M       42.5   4.725

# %%
datadf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
datadf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
datadf.groupby("Item_Fat_Content").mean()
# Out:
#                   Item_Weight  Item_Visibility    Item_MRP  \
# Item_Fat_Content
# LF                  11.606930         0.066628  138.630696
# Low Fat             11.794885         0.064166  140.975221
# Regular             11.505778         0.069564  141.738456
# low fat             11.197078         0.065300  134.571429
# reg                 12.234603         0.066361  136.311966
#
#                   Outlet_Establishment_Year  Item_Outlet_Sales     Profit
# Item_Fat_Content
# LF                              1997.936709        2073.551928  13.312025
# Low Fat                         1997.847121        2164.477336  13.437316
# Regular                         1997.807892        2235.186702  13.379993
# low fat                         1995.883929        2087.740737  13.377679
# reg                             1999.341880        1962.192268  13.587179

# %%
datadf.groupby("Item_Fat_Content")["Profit"].mean()
# Out:
# Item_Fat_Content
# LF         13.312025
# Low Fat    13.437316
# Regular    13.379993
# low fat    13.377679
# reg        13.587179
# Name: Profit, dtype: float64

# %%
datadf.groupby("Outlet_Size")["Item_Outlet_Sales"].sum()
# Out:
# Outlet_Size
# High      2.142664e+06
# Medium    1.188225e+07
# Small     4.566212e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
# display the total sale and avg sale 
datadf.groupby("Outlet_Size").agg({"Item_Outlet_Sales":["mean","sum"]})
# Out:
#             Item_Outlet_Sales
#                          mean           sum
# Outlet_Size
# High              2298.995256  2.142664e+06
# Medium            2283.730470  1.188225e+07
# Small             1912.149161  4.566212e+06

# %%
datadf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
# display the average sale on each item type in every outlet size

datadf.groupby(["Item_Type","Outlet_Size"])["Item_Outlet_Sales"].mean()
# Out:
# Item_Type              Outlet_Size
# Baking Goods           High           2050.901134
#                        Medium         2044.572273
#                        Small          1724.681911
# Breads                 High           2080.731528
#                        Medium         2244.802689
#                        Small          2158.795546
# Breakfast              High           2104.286508
#                        Medium         2290.501060
#                        Small          1715.988533
# Canned                 High           2211.265203
#                        Medium         2316.837355
#                        Small          2038.457667
# Dairy                  High           2453.181713
#                        Medium         2351.587472
#                        Small          1900.495836
# Frozen Foods           High           2214.096189
#                        Medium         2233.128106
#                        Small          1895.489818
# ...

# %%
datadf.groupby(["Item_Type","Outlet_Size"]).agg({"Item_Outlet_Sales":["mean","sum","std"],"Profit":["mean","sum"]})
# Out:
#                                   Item_Outlet_Sales                \
#                                                mean           sum
# Item_Type             Outlet_Size
# Baking Goods          High              2050.901134  1.497158e+05
#                       Medium            2044.572273  7.932940e+05
#                       Small             1724.681911  3.225155e+05
# Breads                High              2080.731528  5.201829e+04
#                       Medium            2244.802689  3.479444e+05
#                       Small             2158.795546  1.532745e+05
# Breakfast             High              2104.286508  2.735572e+04
#                       Medium            2290.501060  1.534636e+05
#                       Small             1715.988533  5.147966e+04
# Canned                High              2211.265203  1.437322e+05
#                       Medium            2316.837355  9.151508e+05
#                       Small             2038.457667  3.852685e+05
# ...

# %%
# concat & merging

df1=pd.DataFrame({"Name":["Kumar","Preethi","karan","john"],"Age":[34,56,78,90]})
df1
# Out:
#       Name  Age
# 0    Kumar   34
# 1  Preethi   56
# 2    karan   78
# 3     john   90

# %%
df2=pd.DataFrame({"Name":["Kumar","Preethi","karan","john"],"Qualification":["B.E","MBA","B.Sc","CA"]})
df2
# Out:
#       Name Qualification
# 0    Kumar           B.E
# 1  Preethi           MBA
# 2    karan          B.Sc
# 3     john            CA

# %%
pd.concat([df1,df2])   # axis not mentioned, so by default it takes 0 which is row wise
# Out:
#       Name   Age Qualification
# 0    Kumar  34.0           NaN
# 1  Preethi  56.0           NaN
# 2    karan  78.0           NaN
# 3     john  90.0           NaN
# 0    Kumar   NaN           B.E
# 1  Preethi   NaN           MBA
# 2    karan   NaN          B.Sc
# 3     john   NaN            CA

# %%
d=pd.concat([df1,df2],axis=1) # axis = 1 is column wise it'll concat
d
# Out:
#       Name  Age     Name Qualification
# 0    Kumar   34    Kumar           B.E
# 1  Preethi   56  Preethi           MBA
# 2    karan   78    karan          B.Sc
# 3     john   90     john            CA

# %%
# drop the duplicate columns

d.loc[:,~d.columns.duplicated()]  # ~ is called Tilde
# Out:
#       Name  Age Qualification
# 0    Kumar   34           B.E
# 1  Preethi   56           MBA
# 2    karan   78          B.Sc
# 3     john   90            CA

# %%
d.loc[:,d.columns.duplicated()]
# Out:
#       Name
# 0    Kumar
# 1  Preethi
# 2    karan
# 3     john

# %%
# <b>merge</b>
# inner ---> default
# left
# right
# outer

# %%
df1=pd.DataFrame({"Name":["kumar","dan","kennady","Ram"],"Age":[23,67,89,62]})
df1
# Out:
#       Name  Age
# 0    kumar   23
# 1      dan   67
# 2  kennady   89
# 3      Ram   62

# %%
df2=pd.DataFrame({"Name":["lena","dan","kennady","Ram"],"Age":[23,67,89,56]})
df2
# Out:
#       Name  Age
# 0     lena   23
# 1      dan   67
# 2  kennady   89
# 3      Ram   56

# %%
pd.merge(df1,df2)   # by default it will take inner join
# Out:
#       Name  Age
# 0      dan   67
# 1  kennady   89

# %%
pd.merge(df1,df2, on="Age")   # inner join by default
# Out:
#     Name_x  Age   Name_y
# 0    kumar   23     lena
# 1      dan   67      dan
# 2  kennady   89  kennady

# %%
pd.merge(df1,df2, on="Name")   # inner join by default
# Out:
#       Name  Age_x  Age_y
# 0      dan     67     67
# 1  kennady     89     89
# 2      Ram     62     56

# %%
pd.merge(df1,df2, on="Name", how="left")  # left join is data of df1 & df2 from left side which is df1
# Out:
#       Name  Age_x  Age_y
# 0    kumar     23    NaN
# 1      dan     67   67.0
# 2  kennady     89   89.0
# 3      Ram     62   56.0

# %%
pd.merge(df1,df2, on="Name", how="right")   # left join is data of df1 & df2 from right side which is df2
# Out:
#       Name  Age_x  Age_y
# 0     lena    NaN     23
# 1      dan   67.0     67
# 2  kennady   89.0     89
# 3      Ram   62.0     56

# %%
pd.merge(df1,df2, on="Name", how="outer")
# Out:
#       Name  Age_x  Age_y
# 0    kumar   23.0    NaN
# 1      dan   67.0   67.0
# 2  kennady   89.0   89.0
# 3      Ram   62.0   56.0
# 4     lena    NaN   23.0

# %%
datadf.to_csv("k_circle_sales1.csv")
